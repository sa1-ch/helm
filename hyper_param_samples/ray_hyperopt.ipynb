# %%
import ray
from ray import tune
from ray.tune.schedulers import AsyncHyperBandScheduler
from ray.tune.suggest.hyperopt import HyperOptSearch
from hyperopt.pyll.base import scope
from hyperopt import hp

from data_and_regressor import get_data
from sklearn.ensemble import GradientBoostingRegressor
import numpy as np

X, y, n_features = get_data()
from sklearn.model_selection import cross_val_score

# %%
@scope.define
def to_int(x):
    return 1 if x==0 else x

# %%
@scope.define
def to_abs(x):
    return abs(x)

# %%
# In some environment hp.randint is not working
space = {
    "learning_rate": scope.to_abs(hp.uniform("learning_rate", 10 ** -5, 1)),
    "max_depth": scope.to_int(hp.randint("max_depth", 5)),
    "max_features": scope.to_int(hp.randint("max_features", 13)),
    "min_samples_split": scope.to_int(hp.randint("min_samples_split", 100)),
    "min_samples_leaf": scope.to_int(hp.randint("min_samples_leaf", 100)),
}

# %%
def objective(params, reporter):
    """
        Function to minimize
    """
    reg = GradientBoostingRegressor(n_estimators=50, random_state=0)
    reg.set_params(**params)

    reporter(
        loss=-np.mean(
            cross_val_score(
                reg, X, y, cv=5, n_jobs=-1, scoring="neg_mean_absolute_error"
            )
        )
    )

# %%
ray.init(object_store_memory=10**9, memory=10**9)
# Out:
# 2020-04-24 03:32:13,950	INFO resource_spec.py:212 -- Starting Ray with 0.93 GiB memory available for workers and up to 0.93 GiB for objects. You can adjust these settings with ray.init(memory=<bytes>, object_store_memory=<bytes>).
# 2020-04-24 03:32:14,379	INFO services.py:1148 -- View the Ray dashboard at localhost:8265
# {'node_ip_address': '10.16.33.136',
#  'redis_address': '10.16.33.136:57689',
#  'object_store_address': '/tmp/ray/session_2020-04-24_03-32-13_949497_1117/sockets/plasma_store',
#  'raylet_socket_name': '/tmp/ray/session_2020-04-24_03-32-13_949497_1117/sockets/raylet',
#  'webui_url': 'localhost:8265',
#  'session_dir': '/tmp/ray/session_2020-04-24_03-32-13_949497_1117'}

# %%
algo = HyperOptSearch(space, max_concurrent=2, metric="loss", mode="min")
config = {
    "num_samples": 50,
}
scheduler = AsyncHyperBandScheduler(metric="loss", mode="min")
analysis = tune.run(objective, search_alg=algo, scheduler=scheduler, **config)
# Out:
# == Status ==<br>Memory usage on this node: 2.3/15.1 GiB<br>Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 64.000: None | Iter 16.000: None | Iter 4.000: None | Iter 1.000: None<br>Resources requested: 1/8 CPUs, 0/0 GPUs, 0.0/0.93 GiB heap, 0.0/0.63 GiB objects<br>Result logdir: /home/leninkumar.vijay/ray_results/objective<br>Number of trials: 2 (1 PENDING, 1 RUNNING)<br><table>
# <thead>
# <tr><th>Trial name        </th><th>status  </th><th>loc  </th><th style="text-align: right;">  learning_rate</th><th style="text-align: right;">  max_depth</th><th style="text-align: right;">  max_features</th><th style="text-align: right;">  min_samples_leaf</th><th style="text-align: right;">  min_samples_split</th></tr>
# </thead>
# <tbody>
# <tr><td>objective_311001a6</td><td>RUNNING </td><td>     </td><td style="text-align: right;">       0.543695</td><td style="text-align: right;">          2</td><td style="text-align: right;">             3</td><td style="text-align: right;">                20</td><td style="text-align: right;">                 20</td></tr>
# <tr><td>objective_31122a6c</td><td>PENDING </td><td>     </td><td style="text-align: right;">       0.962971</td><td style="text-align: right;">          3</td><td style="text-align: right;">             3</td><td style="text-align: right;">                 1</td><td style="text-align: right;">                 25</td></tr>
# </tbody>
# </table><br><br>
# (pid=1166) 2020-04-24 03:32:15,821	INFO trainable.py:217 -- Getting current IP.
# (pid=1168) 2020-04-24 03:32:15,863	INFO trainable.py:217 -- Getting current IP.
# Result for objective_311001a6:
#   date: 2020-04-24_03-32-17
#   done: false
#   experiment_id: 1a8162e7e8954ca9a301e51530b5fb15
#   experiment_tag: 1_learning_rate=0.5437,max_depth=2,max_features=3,min_samples_leaf=20,min_samples_split=20
#   hostname: ip-10-16-33-136.ec2.internal
#   iterations_since_restore: 1
#   loss: 3.6410054356730184
#   node_ip: 10.16.33.136
#   pid: 1166
#   time_since_restore: 1.2209439277648926
#   time_this_iter_s: 1.2209439277648926
#   time_total_s: 1.2209439277648926
#   timestamp: 1587699137
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 311001a6
#
# Result for objective_31122a6c:
#   date: 2020-04-24_03-32-17
#   done: true
#   experiment_id: 308c7d38146748ce9b5c304329d9c8d6
#   experiment_tag: 2_learning_rate=0.96297,max_depth=3,max_features=3,min_samples_leaf=1,min_samples_split=25
#   hostname: ip-10-16-33-136.ec2.internal
#   iterations_since_restore: 1
#   loss: 4.386601699016301
#   node_ip: 10.16.33.136
#   pid: 1168
#   time_since_restore: 1.3731698989868164
#   time_this_iter_s: 1.3731698989868164
#   time_total_s: 1.3731698989868164
#   timestamp: 1587699137
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 31122a6c
#
# (pid=1169) 2020-04-24 03:32:17,761	INFO trainable.py:217 -- Getting current IP.
# (pid=1170) 2020-04-24 03:32:17,963	INFO trainable.py:217 -- Getting current IP.
# Result for objective_3114f88c:
#   date: 2020-04-24_03-32-18
#   done: false
#   experiment_id: 3da6bcf368c9421783a1a2fea25fa307
#   experiment_tag: 3_learning_rate=0.10682,max_depth=4,max_features=11,min_samples_leaf=70,min_samples_split=18
#   hostname: ip-10-16-33-136.ec2.internal
#   iterations_since_restore: 1
#   loss: 3.479628382436047
#   node_ip: 10.16.33.136
#   pid: 1169
#   time_since_restore: 1.2357196807861328
#   time_this_iter_s: 1.2357196807861328
#   time_total_s: 1.2357196807861328
#   timestamp: 1587699138
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 3114f88c
#
# Result for objective_324130ea:
#   date: 2020-04-24_03-32-19
#   done: true
#   experiment_id: b2b785c1b18549818330d5a23551e1f2
#   experiment_tag: 4_learning_rate=0.53292,max_depth=2,max_features=1,min_samples_leaf=95,min_samples_split=67
#   hostname: ip-10-16-33-136.ec2.internal
#   iterations_since_restore: 1
#   loss: 3.970676640312008
#   node_ip: 10.16.33.136
#   pid: 1170
#   time_since_restore: 1.3062877655029297
#   time_this_iter_s: 1.3062877655029297
#   time_total_s: 1.3062877655029297
#   timestamp: 1587699139
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 324130ea
#
# (pid=1165) 2020-04-24 03:32:19,771	INFO trainable.py:217 -- Getting current IP.
# (pid=1171) 2020-04-24 03:32:19,917	INFO trainable.py:217 -- Getting current IP.
# Result for objective_325de1c2:
#   date: 2020-04-24_03-32-21
#   done: false
#   experiment_id: 4c1bbdec89cf4612a36deb90f989924a
#   experiment_tag: 5_learning_rate=0.10268,max_depth=2,max_features=8,min_samples_leaf=23,min_samples_split=80
#   hostname: ip-10-16-33-136.ec2.internal
#   iterations_since_restore: 1
#   loss: 3.189861568563345
#   node_ip: 10.16.33.136
#   pid: 1165
#   time_since_restore: 1.245586633682251
#   time_this_iter_s: 1.245586633682251
#   time_total_s: 1.245586633682251
#   timestamp: 1587699141
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 325de1c2
# == Status ==<br>Memory usage on this node: 3.8/15.1 GiB<br>Using AsyncHyperBand: num_stopped=2
# Bracket: Iter 64.000: None | Iter 16.000: None | Iter 4.000: None | Iter 1.000: -3.479628382436047<br>Resources requested: 2/8 CPUs, 0/0 GPUs, 0.0/0.93 GiB heap, 0.0/0.63 GiB objects<br>Result logdir: /home/leninkumar.vijay/ray_results/objective<br>Number of trials: 6 (2 RUNNING, 4 TERMINATED)<br><table>
# <thead>
# <tr><th>Trial name        </th><th>status    </th><th>loc              </th><th style="text-align: right;">  learning_rate</th><th style="text-align: right;">  max_depth</th><th style="text-align: right;">  max_features</th><th style="text-align: right;">  min_samples_leaf</th><th style="text-align: right;">  min_samples_split</th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th></tr>
# </thead>
# <tbody>
# <tr><td>objective_311001a6</td><td>TERMINATED</td><td>                 </td><td style="text-align: right;">       0.543695</td><td style="text-align: right;">          2</td><td style="text-align: right;">             3</td><td style="text-align: right;">                20</td><td style="text-align: right;">                 20</td><td style="text-align: right;">     1</td><td style="text-align: right;">         1.22094</td></tr>
# <tr><td>objective_31122a6c</td><td>TERMINATED</td><td>                 </td><td style="text-align: right;">       0.962971</td><td style="text-align: right;">          3</td><td style="text-align: right;">             3</td><td style="text-align: right;">                 1</td><td style="text-align: right;">                 25</td><td style="text-align: right;">     1</td><td style="text-align: right;">         1.37317</td></tr>
# <tr><td>objective_3114f88c</td><td>TERMINATED</td><td>                 </td><td style="text-align: right;">       0.106824</td><td style="text-align: right;">          4</td><td style="text-align: right;">            11</td><td style="text-align: right;">                70</td><td style="text-align: right;">                 18</td><td style="text-align: right;">     1</td><td style="text-align: right;">         1.23572</td></tr>
# <tr><td>objective_324130ea</td><td>TERMINATED</td><td>                 </td><td style="text-align: right;">       0.532924</td><td style="text-align: right;">          2</td><td style="text-align: right;">             1</td><td style="text-align: right;">                95</td><td style="text-align: right;">                 67</td><td style="text-align: right;">     1</td><td style="text-align: right;">         1.30629</td></tr>
# <tr><td>objective_325de1c2</td><td>RUNNING   </td><td>10.16.33.136:1165</td><td style="text-align: right;">       0.102684</td><td style="text-align: right;">          2</td><td style="text-align: right;">             8</td><td style="text-align: right;">                23</td><td style="text-align: right;">                 80</td><td style="text-align: right;">     1</td><td style="text-align: right;">         1.24559</td></tr>
# <tr><td>objective_336c880c</td><td>RUNNING   </td><td>                 </td><td style="text-align: right;">       0.770713</td><td style="text-align: right;">          3</td><td style="text-align: right;">             4</td><td style="text-align: right;">                72</td><td style="text-align: right;">                 48</td><td style="text-align: right;">      </td><td style="text-align: right;">                </td></tr>
# </tbody>
# </table><br><br>
# Result for objective_336c880c:
#   date: 2020-04-24_03-32-21
#   done: true
#   experiment_id: b2e2c3a1ba844670aa99008dc626b0fb
#   experiment_tag: 6_learning_rate=0.77071,max_depth=3,max_features=4,min_samples_leaf=72,min_samples_split=48
#   hostname: ip-10-16-33-136.ec2.internal
#   iterations_since_restore: 1
#   loss: 4.156041871821632
#   node_ip: 10.16.33.136
#   pid: 1171
#   time_since_restore: 1.3430125713348389
#   time_this_iter_s: 1.3430125713348389
#   time_total_s: 1.3430125713348389
#   timestamp: 1587699141
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 336c880c
#
# (pid=1167) 2020-04-24 03:32:21,765	INFO trainable.py:217 -- Getting current IP.
# (pid=1164) 2020-04-24 03:32:21,965	INFO trainable.py:217 -- Getting current IP.
# Result for objective_33949018:
#   date: 2020-04-24_03-32-23
#   done: true
#   experiment_id: 4233645155e74977ba4b2a4c3c1e6b4c
#   experiment_tag: 7_learning_rate=0.53862,max_depth=2,max_features=8,min_samples_leaf=44,min_samples_split=9
#   hostname: ip-10-16-33-136.ec2.internal
#   iterations_since_restore: 1
#   loss: 3.638323812012703
#   node_ip: 10.16.33.136
#   pid: 1167
#   time_since_restore: 1.341151237487793
#   time_this_iter_s: 1.341151237487793
#   time_total_s: 1.341151237487793
#   timestamp: 1587699143
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: '33949018'
#
# Result for objective_34a181fa:
#   date: 2020-04-24_03-32-23
#   done: false
#   experiment_id: 8273d216304f4605bedcedfe9e903af5
#   experiment_tag: 8_learning_rate=0.43016,max_depth=1,max_features=11,min_samples_leaf=58,min_samples_split=10
#   hostname: ip-10-16-33-136.ec2.internal
#   iterations_since_restore: 1
#   loss: 3.365889304075053
#   node_ip: 10.16.33.136
#   pid: 1164
#   time_since_restore: 1.2407147884368896
#   time_this_iter_s: 1.2407147884368896
#   time_total_s: 1.2407147884368896
#   timestamp: 1587699143
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 34a181fa
#
# (pid=1458) 2020-04-24 03:32:24,366	INFO trainable.py:217 -- Getting current IP.
# (pid=1463) 2020-04-24 03:32:24,424	INFO trainable.py:217 -- Getting current IP.
# Result for objective_35e0974a:
#   date: 2020-04-24_03-32-25
#   done: true
#   experiment_id: 33ee29cfde5b44aca5f9cd0c5e9fae55
#   experiment_tag: 10_learning_rate=0.37345,max_depth=1,max_features=1,min_samples_leaf=41,min_samples_split=51
#   hostname: ip-10-16-33-136.ec2.internal
#   iterations_since_restore: 1
#   loss: 3.8859915147020745
#   node_ip: 10.16.33.136
#   pid: 1458
#   time_since_restore: 1.3325717449188232
#   time_this_iter_s: 1.3325717449188232
#   time_total_s: 1.3325717449188232
#   timestamp: 1587699145
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 35e0974a
#
# Result for objective_34c6ae58:
#   date: 2020-04-24_03-32-25
#   done: true
#   experiment_id: 4a7fb35960d74d2e8548db5be3b493b4
#   experiment_tag: 9_learning_rate=0.076498,max_depth=1,max_features=10,min_samples_leaf=33,min_samples_split=36
#   hostname: ip-10-16-33-136.ec2.internal
#   iterations_since_restore: 1
#   loss: 3.550558763157118
#   node_ip: 10.16.33.136
#   pid: 1463
#   time_since_restore: 1.3450367450714111
#   time_this_iter_s: 1.3450367450714111
#   time_total_s: 1.3450367450714111
#   timestamp: 1587699145
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 34c6ae58
#
# (pid=1474) 2020-04-24 03:32:26,400	INFO trainable.py:217 -- Getting current IP.
# (pid=1459) 2020-04-24 03:32:26,533	INFO trainable.py:217 -- Getting current IP.
# Result for objective_35efe902:
#   date: 2020-04-24_03-32-27
#   done: true
#   experiment_id: 0ec16f540a5d4fa98557a1f158f27547
#   experiment_tag: 11_learning_rate=0.43894,max_depth=3,max_features=12,min_samples_leaf=93,min_samples_split=89
#   hostname: ip-10-16-33-136.ec2.internal
#   iterations_since_restore: 1
#   loss: 3.993892555121292
#   node_ip: 10.16.33.136
#   pid: 1474
#   time_since_restore: 1.3485937118530273
#   time_this_iter_s: 1.3485937118530273
#   time_total_s: 1.3485937118530273
#   timestamp: 1587699147
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 35efe902
# == Status ==<br>Memory usage on this node: 9.2/15.1 GiB<br>Using AsyncHyperBand: num_stopped=7
# Bracket: Iter 64.000: None | Iter 16.000: None | Iter 4.000: None | Iter 1.000: -3.515093572796583<br>Resources requested: 1/8 CPUs, 0/0 GPUs, 0.0/0.93 GiB heap, 0.0/0.63 GiB objects<br>Result logdir: /home/leninkumar.vijay/ray_results/objective<br>Number of trials: 12 (1 RUNNING, 11 TERMINATED)<br><table>
# <thead>
# <tr><th>Trial name        </th><th>status    </th><th>loc  </th><th style="text-align: right;">  learning_rate</th><th style="text-align: right;">  max_depth</th><th style="text-align: right;">  max_features</th><th style="text-align: right;">  min_samples_leaf</th><th style="text-align: right;">  min_samples_split</th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th></tr>
# </thead>
# <tbody>
# <tr><td>objective_311001a6</td><td>TERMINATED</td><td>     </td><td style="text-align: right;">      0.543695 </td><td style="text-align: right;">          2</td><td style="text-align: right;">             3</td><td style="text-align: right;">                20</td><td style="text-align: right;">                 20</td><td style="text-align: right;">     1</td><td style="text-align: right;">         1.22094</td></tr>
# <tr><td>objective_31122a6c</td><td>TERMINATED</td><td>     </td><td style="text-align: right;">      0.962971 </td><td style="text-align: right;">          3</td><td style="text-align: right;">             3</td><td style="text-align: right;">                 1</td><td style="text-align: right;">                 25</td><td style="text-align: right;">     1</td><td style="text-align: right;">         1.37317</td></tr>
# <tr><td>objective_3114f88c</td><td>TERMINATED</td><td>     </td><td style="text-align: right;">      0.106824 </td><td style="text-align: right;">          4</td><td style="text-align: right;">            11</td><td style="text-align: right;">                70</td><td style="text-align: right;">                 18</td><td style="text-align: right;">     1</td><td style="text-align: right;">         1.23572</td></tr>
# <tr><td>objective_324130ea</td><td>TERMINATED</td><td>     </td><td style="text-align: right;">      0.532924 </td><td style="text-align: right;">          2</td><td style="text-align: right;">             1</td><td style="text-align: right;">                95</td><td style="text-align: right;">                 67</td><td style="text-align: right;">     1</td><td style="text-align: right;">         1.30629</td></tr>
# <tr><td>objective_325de1c2</td><td>TERMINATED</td><td>     </td><td style="text-align: right;">      0.102684 </td><td style="text-align: right;">          2</td><td style="text-align: right;">             8</td><td style="text-align: right;">                23</td><td style="text-align: right;">                 80</td><td style="text-align: right;">     1</td><td style="text-align: right;">         1.24559</td></tr>
# <tr><td>objective_336c880c</td><td>TERMINATED</td><td>     </td><td style="text-align: right;">      0.770713 </td><td style="text-align: right;">          3</td><td style="text-align: right;">             4</td><td style="text-align: right;">                72</td><td style="text-align: right;">                 48</td><td style="text-align: right;">     1</td><td style="text-align: right;">         1.34301</td></tr>
# <tr><td>objective_33949018</td><td>TERMINATED</td><td>     </td><td style="text-align: right;">      0.538621 </td><td style="text-align: right;">          2</td><td style="text-align: right;">             8</td><td style="text-align: right;">                44</td><td style="text-align: right;">                  9</td><td style="text-align: right;">     1</td><td style="text-align: right;">         1.34115</td></tr>
# <tr><td>objective_34a181fa</td><td>TERMINATED</td><td>     </td><td style="text-align: right;">      0.430157 </td><td style="text-align: right;">          1</td><td style="text-align: right;">            11</td><td style="text-align: right;">                58</td><td style="text-align: right;">                 10</td><td style="text-align: right;">     1</td><td style="text-align: right;">         1.24071</td></tr>
# <tr><td>objective_34c6ae58</td><td>TERMINATED</td><td>     </td><td style="text-align: right;">      0.0764977</td><td style="text-align: right;">          1</td><td style="text-align: right;">            10</td><td style="text-align: right;">                33</td><td style="text-align: right;">                 36</td><td style="text-align: right;">     1</td><td style="text-align: right;">         1.34504</td></tr>
# <tr><td>objective_35e0974a</td><td>TERMINATED</td><td>     </td><td style="text-align: right;">      0.373454 </td><td style="text-align: right;">          1</td><td style="text-align: right;">             1</td><td style="text-align: right;">                41</td><td style="text-align: right;">                 51</td><td style="text-align: right;">     1</td><td style="text-align: right;">         1.33257</td></tr>
# <tr><td>objective_35efe902</td><td>TERMINATED</td><td>     </td><td style="text-align: right;">      0.438939 </td><td style="text-align: right;">          3</td><td style="text-align: right;">            12</td><td style="text-align: right;">                93</td><td style="text-align: right;">                 89</td><td style="text-align: right;">     1</td><td style="text-align: right;">         1.34859</td></tr>
# <tr><td>objective_376ff786</td><td>RUNNING   </td><td>     </td><td style="text-align: right;">      0.885659 </td><td style="text-align: right;">          4</td><td style="text-align: right;">             5</td><td style="text-align: right;">                84</td><td style="text-align: right;">                 23</td><td style="text-align: right;">      </td><td style="text-align: right;">                </td></tr>
# </tbody>
# </table><br><br>
# Result for objective_376ff786:
#   date: 2020-04-24_03-32-27
#   done: true
#   experiment_id: 7b730c7cd5114f0b97e0498c73fef175
#   experiment_tag: 12_learning_rate=0.88566,max_depth=4,max_features=5,min_samples_leaf=84,min_samples_split=23
#   hostname: ip-10-16-33-136.ec2.internal
#   iterations_since_restore: 1
#   loss: 4.221668429970091
#   node_ip: 10.16.33.136
#   pid: 1459
#   time_since_restore: 1.2649900913238525
#   time_this_iter_s: 1.2649900913238525
#   time_total_s: 1.2649900913238525
#   timestamp: 1587699147
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 376ff786
#
# (pid=1460) 2020-04-24 03:32:28,568	INFO trainable.py:217 -- Getting current IP.
# (pid=1613) 2020-04-24 03:32:29,113	INFO trainable.py:217 -- Getting current IP.
# Result for objective_37796d34:
#   date: 2020-04-24_03-32-29
#   done: true
#   experiment_id: 16489cc6b89240499179daf26e7091fc
#   experiment_tag: 13_learning_rate=0.77371,max_depth=4,max_features=5,min_samples_leaf=98,min_samples_split=81
#   hostname: ip-10-16-33-136.ec2.internal
#   iterations_since_restore: 1
#   loss: 4.510676214322982
#   node_ip: 10.16.33.136
#   pid: 1460
#   time_since_restore: 1.0724670886993408
#   time_this_iter_s: 1.0724670886993408
#   time_total_s: 1.0724670886993408
#   timestamp: 1587699149
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 37796d34
#
# Result for objective_38a569ce:
#   date: 2020-04-24_03-32-30
#   done: false
#   experiment_id: db471b26640e4e4db96e364676e05a4e
#   experiment_tag: 14_learning_rate=0.49186,max_depth=3,max_features=1,min_samples_leaf=22,min_samples_split=75
#   hostname: ip-10-16-33-136.ec2.internal
#   iterations_since_restore: 1
#   loss: 3.4529007675080394
#   node_ip: 10.16.33.136
#   pid: 1613
#   time_since_restore: 1.0492022037506104
#   time_this_iter_s: 1.0492022037506104
#   time_total_s: 1.0492022037506104
#   timestamp: 1587699150
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 38a569ce
#
# (pid=1669) 2020-04-24 03:32:31,093	INFO trainable.py:217 -- Getting current IP.
# (pid=1675) 2020-04-24 03:32:31,568	INFO trainable.py:217 -- Getting current IP.
# Result for objective_38b30110:
#   date: 2020-04-24_03-32-32
#   done: true
#   experiment_id: 0ec37bd34e564226809865e3726e1bcb
#   experiment_tag: 15_learning_rate=0.70138,max_depth=4,max_features=7,min_samples_leaf=82,min_samples_split=85
#   hostname: ip-10-16-33-136.ec2.internal
#   iterations_since_restore: 1
#   loss: 3.904016413985809
#   node_ip: 10.16.33.136
#   pid: 1669
#   time_since_restore: 1.101515769958496
#   time_this_iter_s: 1.101515769958496
#   time_total_s: 1.101515769958496
#   timestamp: 1587699152
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 38b30110
#
# Result for objective_39c3b0ea:
#   date: 2020-04-24_03-32-32
#   done: false
#   experiment_id: 0ee6bf64cfd2461c864914c4dd038693
#   experiment_tag: 16_learning_rate=0.39356,max_depth=4,max_features=3,min_samples_leaf=14,min_samples_split=5
#   hostname: ip-10-16-33-136.ec2.internal
#   iterations_since_restore: 1
#   loss: 3.109257499132554
#   node_ip: 10.16.33.136
#   pid: 1675
#   time_since_restore: 1.1328721046447754
#   time_this_iter_s: 1.1328721046447754
#   time_total_s: 1.1328721046447754
#   timestamp: 1587699152
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 39c3b0ea
#
# (pid=1684) 2020-04-24 03:32:32,980	INFO trainable.py:217 -- Getting current IP.
# (pid=1672) 2020-04-24 03:32:33,577	INFO trainable.py:217 -- Getting current IP.
# Result for objective_3a11d068:
#   date: 2020-04-24_03-32-34
#   done: false
#   experiment_id: 5a505ec4de454a37b0daa1b2c6ba1bb3
#   experiment_tag: 17_learning_rate=0.21171,max_depth=4,max_features=8,min_samples_leaf=3,min_samples_split=41
#   hostname: ip-10-16-33-136.ec2.internal
#   iterations_since_restore: 1
#   loss: 2.873927761794698
#   node_ip: 10.16.33.136
#   pid: 1684
#   time_since_restore: 1.1096558570861816
#   time_this_iter_s: 1.1096558570861816
#   time_total_s: 1.1096558570861816
#   timestamp: 1587699154
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 3a11d068
# == Status ==<br>Memory usage on this node: 13.9/15.1 GiB: ***LOW MEMORY*** less than 10% of the memory on this node is available for use. This can cause unexpected crashes. Consider reducing the memory used by your application or reducing the Ray object store size by setting `object_store_memory` when calling `ray.init`.<br>Using AsyncHyperBand: num_stopped=10
# Bracket: Iter 64.000: None | Iter 16.000: None | Iter 4.000: None | Iter 1.000: -3.4529007675080394<br>Resources requested: 2/8 CPUs, 0/0 GPUs, 0.0/0.93 GiB heap, 0.0/0.63 GiB objects<br>Result logdir: /home/leninkumar.vijay/ray_results/objective<br>Number of trials: 18 (2 RUNNING, 16 TERMINATED)<br><table>
# <thead>
# <tr><th>Trial name        </th><th>status    </th><th>loc              </th><th style="text-align: right;">  learning_rate</th><th style="text-align: right;">  max_depth</th><th style="text-align: right;">  max_features</th><th style="text-align: right;">  min_samples_leaf</th><th style="text-align: right;">  min_samples_split</th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th></tr>
# </thead>
# <tbody>
# <tr><td>objective_311001a6</td><td>TERMINATED</td><td>                 </td><td style="text-align: right;">      0.543695 </td><td style="text-align: right;">          2</td><td style="text-align: right;">             3</td><td style="text-align: right;">                20</td><td style="text-align: right;">                 20</td><td style="text-align: right;">     1</td><td style="text-align: right;">         1.22094</td></tr>
# <tr><td>objective_31122a6c</td><td>TERMINATED</td><td>                 </td><td style="text-align: right;">      0.962971 </td><td style="text-align: right;">          3</td><td style="text-align: right;">             3</td><td style="text-align: right;">                 1</td><td style="text-align: right;">                 25</td><td style="text-align: right;">     1</td><td style="text-align: right;">         1.37317</td></tr>
# <tr><td>objective_3114f88c</td><td>TERMINATED</td><td>                 </td><td style="text-align: right;">      0.106824 </td><td style="text-align: right;">          4</td><td style="text-align: right;">            11</td><td style="text-align: right;">                70</td><td style="text-align: right;">                 18</td><td style="text-align: right;">     1</td><td style="text-align: right;">         1.23572</td></tr>
# <tr><td>objective_324130ea</td><td>TERMINATED</td><td>                 </td><td style="text-align: right;">      0.532924 </td><td style="text-align: right;">          2</td><td style="text-align: right;">             1</td><td style="text-align: right;">                95</td><td style="text-align: right;">                 67</td><td style="text-align: right;">     1</td><td style="text-align: right;">         1.30629</td></tr>
# <tr><td>objective_325de1c2</td><td>TERMINATED</td><td>                 </td><td style="text-align: right;">      0.102684 </td><td style="text-align: right;">          2</td><td style="text-align: right;">             8</td><td style="text-align: right;">                23</td><td style="text-align: right;">                 80</td><td style="text-align: right;">     1</td><td style="text-align: right;">         1.24559</td></tr>
# <tr><td>objective_336c880c</td><td>TERMINATED</td><td>                 </td><td style="text-align: right;">      0.770713 </td><td style="text-align: right;">          3</td><td style="text-align: right;">             4</td><td style="text-align: right;">                72</td><td style="text-align: right;">                 48</td><td style="text-align: right;">     1</td><td style="text-align: right;">         1.34301</td></tr>
# <tr><td>objective_33949018</td><td>TERMINATED</td><td>                 </td><td style="text-align: right;">      0.538621 </td><td style="text-align: right;">          2</td><td style="text-align: right;">             8</td><td style="text-align: right;">                44</td><td style="text-align: right;">                  9</td><td style="text-align: right;">     1</td><td style="text-align: right;">         1.34115</td></tr>
# <tr><td>objective_34a181fa</td><td>TERMINATED</td><td>                 </td><td style="text-align: right;">      0.430157 </td><td style="text-align: right;">          1</td><td style="text-align: right;">            11</td><td style="text-align: right;">                58</td><td style="text-align: right;">                 10</td><td style="text-align: right;">     1</td><td style="text-align: right;">         1.24071</td></tr>
# <tr><td>objective_34c6ae58</td><td>TERMINATED</td><td>                 </td><td style="text-align: right;">      0.0764977</td><td style="text-align: right;">          1</td><td style="text-align: right;">            10</td><td style="text-align: right;">                33</td><td style="text-align: right;">                 36</td><td style="text-align: right;">     1</td><td style="text-align: right;">         1.34504</td></tr>
# <tr><td>objective_35e0974a</td><td>TERMINATED</td><td>                 </td><td style="text-align: right;">      0.373454 </td><td style="text-align: right;">          1</td><td style="text-align: right;">             1</td><td style="text-align: right;">                41</td><td style="text-align: right;">                 51</td><td style="text-align: right;">     1</td><td style="text-align: right;">         1.33257</td></tr>
# <tr><td>objective_35efe902</td><td>TERMINATED</td><td>                 </td><td style="text-align: right;">      0.438939 </td><td style="text-align: right;">          3</td><td style="text-align: right;">            12</td><td style="text-align: right;">                93</td><td style="text-align: right;">                 89</td><td style="text-align: right;">     1</td><td style="text-align: right;">         1.34859</td></tr>
# <tr><td>objective_376ff786</td><td>TERMINATED</td><td>                 </td><td style="text-align: right;">      0.885659 </td><td style="text-align: right;">          4</td><td style="text-align: right;">             5</td><td style="text-align: right;">                84</td><td style="text-align: right;">                 23</td><td style="text-align: right;">     1</td><td style="text-align: right;">         1.26499</td></tr>
# <tr><td>objective_37796d34</td><td>TERMINATED</td><td>                 </td><td style="text-align: right;">      0.773705 </td><td style="text-align: right;">          4</td><td style="text-align: right;">             5</td><td style="text-align: right;">                98</td><td style="text-align: right;">                 81</td><td style="text-align: right;">     1</td><td style="text-align: right;">         1.07247</td></tr>
# <tr><td>objective_38a569ce</td><td>TERMINATED</td><td>                 </td><td style="text-align: right;">      0.491862 </td><td style="text-align: right;">          3</td><td style="text-align: right;">             1</td><td style="text-align: right;">                22</td><td style="text-align: right;">                 75</td><td style="text-align: right;">     1</td><td style="text-align: right;">         1.0492 </td></tr>
# <tr><td>objective_38b30110</td><td>TERMINATED</td><td>                 </td><td style="text-align: right;">      0.701383 </td><td style="text-align: right;">          4</td><td style="text-align: right;">             7</td><td style="text-align: right;">                82</td><td style="text-align: right;">                 85</td><td style="text-align: right;">     1</td><td style="text-align: right;">         1.10152</td></tr>
# <tr><td>objective_39c3b0ea</td><td>TERMINATED</td><td>                 </td><td style="text-align: right;">      0.393558 </td><td style="text-align: right;">          4</td><td style="text-align: right;">             3</td><td style="text-align: right;">                14</td><td style="text-align: right;">                  5</td><td style="text-align: right;">     1</td>
# Result for objective_3b495f5a:
#   date: 2020-04-24_03-32-34
#   done: true
#   experiment_id: a628c1d122654747b452e7fc8bdf825b
#   experiment_tag: 18_learning_rate=0.89851,max_depth=1,max_features=2,min_samples_leaf=28,min_samples_split=54
#   hostname: ip-10-16-33-136.ec2.internal
#   iterations_since_restore: 1
#   loss: 3.6948824373605276
#   node_ip: 10.16.33.136
#   pid: 1672
#   time_since_restore: 1.0257251262664795
#   time_this_iter_s: 1.0257251262664795
#   time_total_s: 1.0257251262664795
#   timestamp: 1587699154
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 3b495f5a
#
# (pid=1671) 2020-04-24 03:32:34,981	INFO trainable.py:217 -- Getting current IP.
# Result for objective_3b954622:
#   date: 2020-04-24_03-32-35
#   done: false
#   experiment_id: b045ae73ea5349978608f1a75d7f2a0c
#   experiment_tag: 19_learning_rate=0.14921,max_depth=1,max_features=9,min_samples_leaf=3,min_samples_split=6
#   hostname: ip-10-16-33-136.ec2.internal
#   iterations_since_restore: 1
#   loss: 3.31158365759554
#   node_ip: 10.16.33.136
#   pid: 1671
#   time_since_restore: 0.9186029434204102
#   time_this_iter_s: 0.9186029434204102
#   time_total_s: 0.9186029434204102
#   timestamp: 1587699155
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 3b954622
# 2020-04-24 03:32:36,113	ERROR trial_runner.py:521 -- Trial objective_3c73fe12: Error processing event.
# Traceback (most recent call last):
#   File "/home/leninkumar.vijay/miniconda3/lib/python3.6/site-packages/ray/tune/trial_runner.py", line 467, in _process_trial
#     result = self.trial_executor.fetch_result(trial)
#   File "/home/leninkumar.vijay/miniconda3/lib/python3.6/site-packages/ray/tune/ray_trial_executor.py", line 381, in fetch_result
#     result = ray.get(trial_future[0], DEFAULT_GET_TIMEOUT)
#   File "/home/leninkumar.vijay/miniconda3/lib/python3.6/site-packages/ray/worker.py", line 1513, in get
#     raise value.as_instanceof_cause()
# ray.exceptions.RayTaskError(RayOutOfMemoryError): ray::IDLE (pid=1815, ip=10.16.33.136)
#   File "python/ray/_raylet.pyx", line 414, in ray._raylet.execute_task
#   File "python/ray/_raylet.pyx", line 415, in ray._raylet.execute_task
#   File "/home/leninkumar.vijay/miniconda3/lib/python3.6/site-packages/ray/memory_monitor.py", line 120, in raise_if_low_memory
#     self.error_threshold))
# ray.memory_monitor.RayOutOfMemoryError: More than 95% of the memory on node ip-10-16-33-136.ec2.internal is used (14.61 / 15.1 GB). The top 10 memory consumers are:
#
# PID	MEM	COMMAND
# 1141	12.32GiB	/home/leninkumar.vijay/miniconda3/bin/python -u /home/leninkumar.vijay/miniconda3/lib/python3.6/site
# 22962	0.16GiB	/home/leninkumar.vijay/miniconda3/bin/python -m ipykernel_launcher -f /home/leninkumar.vijay/.local/
# 14192	0.14GiB	/home/leninkumar.vijay/miniconda3/bin/python -m ipykernel_launcher -f /home/leninkumar.vijay/.local/
# 1117	0.12GiB	/home/leninkumar.vijay/miniconda3/bin/python -m ipykernel_launcher -f /home/leninkumar.vijay/.local/
# 26683	0.1GiB	/home/leninkumar.vijay/miniconda3/bin/python -m ipykernel_launcher -f /home/leninkumar.vijay/.local/
# 26518	0.1GiB	/home/leninkumar.vijay/miniconda3/bin/python -m ipykernel_launcher -f /home/leninkumar.vijay/.local/
# 1671	0.08GiB	ray::WrappedFunc.__ray_terminate__()
# 1815	0.08GiB	ray::IDLE
# 8122	0.07GiB	/opt/yum/conda/envs/mlflow-server/bin/python /opt/yum/conda/envs/mlflow-server/bin/gunicorn -b 0.0.0
# 27110	0.07GiB	/opt/yum/conda/envs/mlflow-server/bin/python /opt/yum/conda/envs/mlflow-server/bin/mlflow server --b
#
# In addition, up to 0.05 GiB of shared memory is currently being used by the Ray object store. You can set the object store size with the `object_store_memory` parameter when starting Ray.
# ---
# --- Tip: Use the `ray memory` command to list active objects in the cluster.
# ---
# 2020-04-24 03:32:36,577	ERROR trial_runner.py:521 -- Trial objective_3cb74fd2: Error processing event.
# Traceback (most recent call last):
#   File "/home/leninkumar.vijay/miniconda3/lib/python3.6/site-packages/ray/tune/trial_runner.py", line 467, in _process_trial
#     result = self.trial_executor.fetch_result(trial)
#   File "/home/leninkumar.vijay/miniconda3/lib/python3.6/site-packages/ray/tune/ray_trial_executor.py", line 381, in fetch_result
#     result = ray.get(trial_future[0], DEFAULT_GET_TIMEOUT)
#   File "/home/leninkumar.vijay/miniconda3/lib/python3.6/site-packages/ray/worker.py", line 1513, in get
#     raise value.as_instanceof_cause()
# ray.exceptions.RayTaskError(RayOutOfMemoryError): ray::IDLE (pid=1817, ip=10.16.33.136)
#   File "python/ray/_raylet.pyx", line 414, in ray._raylet.execute_task
#   File "python/ray/_raylet.pyx", line 415, in ray._raylet.execute_task
#   File "/home/leninkumar.vijay/miniconda3/lib/python3.6/site-packages/ray/memory_monitor.py", line 120, in raise_if_low_memory
#     self.error_threshold))
# ray.memory_monitor.RayOutOfMemoryError: More than 95% of the memory on node ip-10-16-33-136.ec2.internal is used (14.77 / 15.1 GB). The top 10 memory consumers are:
#
# PID	MEM	COMMAND
# 1141	12.59GiB	/home/leninkumar.vijay/miniconda3/bin/python -u /home/leninkumar.vijay/miniconda3/lib/python3.6/site
# 22962	0.16GiB	/home/leninkumar.vijay/miniconda3/bin/python -m ipykernel_launcher -f /home/leninkumar.vijay/.local/
# 14192	0.14GiB	/home/leninkumar.vijay/miniconda3/bin/python -m ipykernel_launcher -f /home/leninkumar.vijay/.local/
# 1117	0.12GiB	/home/leninkumar.vijay/miniconda3/bin/python -m ipykernel_launcher -f /home/leninkumar.vijay/.local/
# 26683	0.1GiB	/home/leninkumar.vijay/miniconda3/bin/python -m ipykernel_launcher -f /home/leninkumar.vijay/.local/
# 26518	0.1GiB	/home/leninkumar.vijay/miniconda3/bin/python -m ipykernel_launcher -f /home/leninkumar.vijay/.local/
# 1817	0.08GiB	ray::IDLE
# 8122	0.07GiB	/opt/yum/conda/envs/mlflow-server/bin/python /opt/yum/conda/envs/mlflow-server/bin/gunicorn -b 0.0.0
# 27110	0.07GiB	/opt/yum/conda/envs/mlflow-server/bin/python /opt/yum/conda/envs/mlflow-server/bin/mlflow server --b
# 22953	0.06GiB	/home/leninkumar.vijay/miniconda3/bin/python /home/leninkumar.vijay/miniconda3/bin/jupyter-notebook
#
# In addition, up to 0.05 GiB of shared memory is currently being used by the Ray object store. You can set the object store size with the `object_store_memory` parameter when starting Ray.
# ---
# --- Tip: Use the `ray memory` command to list active objects in the cluster.
# ---

# %%
result_df = analysis.dataframe()

# %%
import matplotlib.pyplot as plt
f, ax = plt.subplots(1)#, figsize=(10,10))
xs = [i for i in range(len(result_df))]
ys = [i for i in result_df.loss]
plt.plot(xs, ys, color='green', marker='o', linestyle='dashed', linewidth=2, markersize=2)

ax.set_xlabel('No of calls', fontsize=12)
ax.set_ylabel('min(x) after n calls', fontsize=12)

# %%
# Don't forget to shut it down
ray.shutdown()
